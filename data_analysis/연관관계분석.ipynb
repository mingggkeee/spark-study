# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/chipotle.csv')

print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
df_tmp = df[['order_id', 'item_name']]
df_tmp_arr = [[] for i in range(1835)]
num = 0
for i in df_tmp['item_name']:
    df_tmp_arr[df_tmp['order_id'][num]].append(i)
    num+=1

# %%
df_tmp_arr.pop(0)
num = 0
for i in df_tmp_arr:
    df_tmp_arr[num] = list(set(df_tmp_arr[num]))
    num+=1
df_tmp_arr
# Out:
# [['Chips and Fresh Tomato Salsa',
#   'Chips and Tomatillo-Green Chili Salsa',
#   'Nantucket Nectar',
#   'Izze'],
#  ['Chicken Bowl'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Steak Burrito', 'Steak Soft Tacos'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chicken Crispy Tacos', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Barbacoa Burrito', 'Nantucket Nectar'],
#  ['Chicken Burrito', 'Izze'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl'],
#  ['Canned Soda', 'Carnitas Burrito'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Carnitas Bowl', 'Bottled Water'],
#  ['Chips and Guacamole',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Soft Tacos'],
#  ['Barbacoa Bowl', 'Chips'],
#  ['Chips and Guacamole',
#   'Chicken Bowl',
#   'Steak Burrito',
#   'Chicken Salad Bowl'],
#  ['Chicken Burrito', 'Steak Burrito', 'Izze'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Steak Bowl', 'Chips and Fresh Tomato Salsa'],
#  ['Barbacoa Soft Tacos', 'Veggie Burrito'],
#  ['Barbacoa Bowl', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Veggie Bowl', 'Steak Soft Tacos'],
#  ['Steak Burrito', 'Steak Soft Tacos'],
#  ['Chicken Burrito', 'Steak Burrito', 'Izze'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Bowl', 'Chips', 'Chicken Soft Tacos'],
#  ['Chips', 'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Steak Soft Tacos'],
#  ['Veggie Bowl', 'Bottled Water', 'Steak Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Carnitas Burrito'],
#  ['Steak Bowl', 'Steak Crispy Tacos'],
#  ['Chips and Guacamole', 'Carnitas Burrito'],
#  ['Barbacoa Bowl', 'Chips and Guacamole'],
#  ['Carnitas Bowl', 'Chicken Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Bowl', 'Steak Burrito', 'Chips and Guacamole'],
#  ['Nantucket Nectar', 'Veggie Burrito'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Guacamole',
#   'Chicken Bowl',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Barbacoa Bowl', 'Chicken Burrito', 'Canned Soda'],
#  ['Chips and Guacamole', 'Steak Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Barbacoa Bowl',
#   'Chips and Guacamole',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chicken Burrito'],
#  ['Chicken Salad Bowl'],
#  ['Barbacoa Bowl', 'Chips and Guacamole'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Veggie Bowl', 'Chicken Bowl'],
#  ['Carnitas Bowl', 'Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Steak Burrito'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Veggie Bowl', 'Steak Burrito'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl', 'Canned Soda'],
#  ['Carnitas Bowl', 'Chips and Tomatillo-Green Chili Salsa', 'Veggie Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Barbacoa Crispy Tacos'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Chicken Burrito', 'Nantucket Nectar'],
#  ['Chicken Burrito', 'Steak Soft Tacos'],
#  ['Chicken Bowl'],
#  ['Steak Burrito'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl', 'Barbacoa Soft Tacos'],
#  ['Chips and Guacamole', 'Veggie Salad Bowl', 'Steak Soft Tacos'],
#  ['Steak Bowl', 'Chicken Burrito'],
#  ['Steak Burrito', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Veggie Bowl', 'Chicken Bowl', 'Chips and Fresh Tomato Salsa'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chips and Guacamole', 'Canned Soda', 'Chicken Bowl'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Nantucket Nectar'],
#  ['Steak Bowl', 'Chicken Bowl', 'Chips'],
#  ['Veggie Bowl', 'Chicken Bowl', 'Chips and Guacamole'],
#  ['Chicken Salad Bowl'],
#  ['Chips and Guacamole', 'Steak Bowl'],
#  ['Chicken Burrito', 'Chicken Bowl', 'Chicken Crispy Tacos'],
#  ['Barbacoa Bowl', 'Chicken Bowl', 'Chips'],
#  ['Chips', 'Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chips', 'Veggie Burrito'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Roasted Chili Corn Salsa',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl'],
#  ['Chips and Tomatillo Green Chili Salsa',
#   'Steak Burrito',
#   'Carnitas Soft Tacos'],
#  ['Chips and Fresh Tomato Salsa', 'Carnitas Burrito'],
#  ['Chicken Burrito'],
#  ['Steak Bowl', 'Chicken Burrito'],
#  ['Chicken Burrito'],
#  ['Canned Soda', 'Steak Burrito', 'Barbacoa Burrito'],
#  ['Chicken Salad', 'Canned Soda'],
#  ['Veggie Bowl', 'Barbacoa Bowl', 'Chicken Bowl', 'Barbacoa Crispy Tacos'],
#  ['Chicken Salad Bowl', 'Chicken Bowl'],
#  ['Steak Bowl', 'Steak Burrito'],
#  ['Steak Bowl', 'Canned Soda'],
#  ['Steak Bowl', 'Canned Soft Drink'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Soft Tacos'],
#  ['Chips and Guacamole', 'Barbacoa Soft Tacos'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Canned Soda', 'Side of Chips', 'Steak Soft Tacos'],
#  ['Steak Salad Bowl'],
#  ['Chicken Bowl', 'Chips'],
#  ['Steak Bowl', 'Veggie Bowl', 'Chips and Guacamole'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Veggie Salad Bowl', 'Steak Soft Tacos'],
#  ['Steak Burrito', '6 Pack Soft Drink'],
#  ['Chips and Tomatillo-Red Chili Salsa', 'Steak Soft Tacos'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Chips'],
#  ['Steak Bowl', 'Side of Chips'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chicken Salad Bowl'],
#  ['Chicken Burrito', 'Bottled Water', 'Canned Soda'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Steak Burrito'],
#  ['Chicken Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chicken Soft Tacos'],
#  ['Steak Burrito', 'Barbacoa Burrito'],
#  ['Steak Bowl', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito', '6 Pack Soft Drink'],
#  ['Canned Soft Drink',
#   'Chips and Fresh Tomato Salsa',
#   'Chips and Guacamole',
#   'Steak Soft Tacos',
#   'Chicken Soft Tacos'],
#  ['Canned Soda', 'Chicken Bowl', 'Chips and Tomatillo-Red Chili Salsa'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Steak Burrito'],
#  ['Chicken Soft Tacos'],
#  ['Chicken Burrito',
#   '6 Pack Soft Drink',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Steak Burrito', 'Izze'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Chicken Crispy Tacos'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Carnitas Burrito'],
#  ['Barbacoa Burrito', 'Bottled Water'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Burrito', 'Steak Burrito', 'Chips'],
#  ['Side of Chips', 'Barbacoa Burrito'],
#  ['Steak Bowl', '6 Pack Soft Drink'],
#  ['Chicken Burrito', 'Steak Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Barbacoa Burrito'],
#  ['Carnitas Bowl', 'Chicken Burrito'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Steak Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Carnitas Soft Tacos', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips'],
#  ['Chicken Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Steak Bowl', 'Canned Soda', 'Side of Chips'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Barbacoa Bowl', '6 Pack Soft Drink'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chips',
#   'Chips and Fresh Tomato Salsa',
#   'Carnitas Burrito',
#   'Chicken Burrito',
#   'Chicken Bowl'],
#  ['Chicken Soft Tacos'],
#  ['Steak Bowl', 'Barbacoa Crispy Tacos', 'Chicken Soft Tacos', 'Izze'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Carnitas Bowl', 'Canned Soda'],
#  ['Nantucket Nectar', 'Veggie Burrito'],
#  ['Canned Soda', 'Steak Crispy Tacos'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole',
#   'Chicken Burrito',
#   'Steak Bowl',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Bowl'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Barbacoa Burrito',
#   'Chicken Burrito',
#   'Veggie Salad Bowl',
#   'Carnitas Soft Tacos',
#   'Chicken Bowl'],
#  ['Chips and Fresh Tomato Salsa',
#   'Chicken Burrito',
#   'Chicken Bowl',
#   'Canned Soft Drink'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Burrito', 'Carnitas Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Barbacoa Bowl', 'Canned Soda', 'Side of Chips'],
#  ['Bottled Water', 'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Barbacoa Crispy Tacos',
#   'Chips',
#   'Veggie Burrito',
#   'Carnitas Burrito',
#   'Chicken Burrito',
#   'Steak Burrito',
#   'Chicken Bowl'],
#  ['Steak Bowl', 'Chicken Bowl', 'Canned Soft Drink', 'Chips and Guacamole'],
#  ['Chips and Guacamole', 'Veggie Salad Bowl', 'Steak Soft Tacos'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Steak Bowl'],
#  ['Chicken Bowl', 'Barbacoa Burrito'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Carnitas Bowl', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Steak Burrito'],
#  ['Burrito'],
#  ['Veggie Bowl', 'Canned Soft Drink', 'Chips and Guacamole', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Crispy Tacos', 'Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Steak Bowl', 'Side of Chips'],
#  ['Chicken Salad Bowl', 'Chicken Bowl'],
#  ['Chicken Salad Bowl'],
#  ['Veggie Bowl', 'Chicken Burrito', 'Chips and Fresh Tomato Salsa'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Carnitas Bowl',
#   'Canned Soft Drink',
#   'Bottled Water',
#   'Steak Burrito',
#   'Chips and Tomatillo Green Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl'],
#  ['Steak Burrito'],
#  ['Carnitas Crispy Tacos',
#   'Chips and Guacamole',
#   'Chicken Burrito',
#   'Steak Burrito',
#   '6 Pack Soft Drink'],
#  ['Chips',
#   'Barbacoa Burrito',
#   'Chips and Guacamole',
#   'Steak Bowl',
#   'Veggie Bowl',
#   'Chicken Bowl'],
#  ['Chips and Roasted Chili Corn Salsa', 'Barbacoa Burrito'],
#  ['Chicken Burrito',
#   'Steak Burrito',
#   'Canned Soft Drink',
#   'Carnitas Soft Tacos'],
#  ['Chicken Salad Bowl',
#   'Chicken Burrito',
#   'Chips and Guacamole',
#   'Steak Soft Tacos'],
#  ['Steak Burrito', 'Barbacoa Burrito'],
#  ['Steak Burrito', 'Barbacoa Burrito'],
#  ['Chips and Tomatillo-Green Chili Salsa', 'Chicken Soft Tacos', 'Izze'],
#  ['Steak Crispy Tacos', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips'],
#  ['Chicken Salad Bowl', 'Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Carnitas Soft Tacos'],
#  ['Chicken Salad Bowl'],
#  ['Barbacoa Bowl', 'Bottled Water', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Steak Bowl'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Burrito', 'Chicken Crispy Tacos', 'Nantucket Nectar'],
#  ['Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Salad Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chicken Burrito', 'Barbacoa Soft Tacos'],
#  ['Steak Salad Bowl'],
#  ['Chips', 'Chicken Bowl', 'Canned Soft Drink', 'Barbacoa Burrito'],
#  ['Veggie Bowl', 'Chips and Guacamole'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chips and Guacamole',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl',
#   'Carnitas Burrito'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Salad Bowl'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Steak Burrito', '6 Pack Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Chicken Soft Tacos'],
#  ['Veggie Bowl', 'Chips and Guacamole'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Canned Soft Drink', 'Bottled Water', 'Carnitas Burrito'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Steak Bowl', 'Carnitas Soft Tacos', 'Chips and Guacamole', 'Steak Salad'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chips and Guacamole',
#   'Bowl',
#   'Chips and Mild Fresh Tomato Salsa',
#   'Burrito'],
#  ['Veggie Bowl', 'Chips and Guacamole'],
#  ['Steak Bowl', 'Chips and Guacamole'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Steak Burrito'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Canned Soft Drink', 'Steak Bowl'],
#  ['Chips and Tomatillo-Red Chili Salsa', 'Carnitas Burrito'],
#  ['Chicken Salad Bowl', 'Chips and Guacamole', 'Canned Soft Drink'],
#  ['Canned Soda', 'Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Bottled Water', 'Canned Soda'],
#  ['Chicken Salad Bowl',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Canned Soft Drink'],
#  ['Chicken Bowl', 'Bottled Water'],
#  ['Chips and Roasted Chili Corn Salsa', 'Steak Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Steak Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Side of Chips', 'Barbacoa Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Bowl', '6 Pack Soft Drink'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito', 'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Crispy Tacos', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Veggie Bowl', 'Canned Soft Drink', 'Steak Burrito', 'Veggie Soft Tacos'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Steak Burrito'],
#  ['6 Pack Soft Drink', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chicken Burrito', 'Steak Salad Bowl'],
#  ['Barbacoa Bowl', 'Side of Chips'],
#  ['Steak Bowl', 'Carnitas Soft Tacos', 'Chips and Guacamole', 'Steak Salad'],
#  ['Steak Bowl', 'Chips', 'Barbacoa Burrito'],
#  ['Burrito'],
#  ['Chicken Salad Bowl', 'Veggie Burrito'],
#  ['Barbacoa Crispy Tacos', 'Chips and Guacamole'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Canned Soft Drink', 'Chicken Crispy Tacos', 'Carnitas Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Steak Crispy Tacos'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', 'Bottled Water', 'Canned Soda'],
#  ['Chips and Tomatillo Green Chili Salsa',
#   'Veggie Soft Tacos',
#   'Canned Soft Drink'],
#  ['Steak Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Barbacoa Bowl', 'Side of Chips'],
#  ['Barbacoa Bowl', 'Chicken Bowl'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Steak Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Salad Bowl'],
#  ['Canned Soda',
#   'Chips and Guacamole',
#   'Bottled Water',
#   'Carnitas Soft Tacos',
#   'Chicken Bowl'],
#  ['Carnitas Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Steak Bowl'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Barbacoa Crispy Tacos',
#   'Carnitas Bowl',
#   'Chips',
#   'Chicken Crispy Tacos',
#   'Veggie Bowl'],
#  ['Chicken Burrito', 'Carnitas Burrito'],
#  ['Chips and Guacamole',
#   'Chicken Bowl',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Barbacoa Bowl',
#   'Veggie Bowl',
#   'Chips and Roasted Chili Corn Salsa',
#   'Steak Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Veggie Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Carnitas Bowl', 'Chips and Guacamole'],
#  ['Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Barbacoa Soft Tacos'],
#  ['Chicken Burrito', 'Barbacoa Burrito'],
#  ['Steak Burrito'],
#  ['Steak Burrito'],
#  ['Chicken Salad Bowl'],
#  ['Canned Soft Drink', 'Chicken Crispy Tacos', 'Carnitas Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chicken Soft Tacos'],
#  ['Bottled Water', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Chicken Soft Tacos'],
#  ['6 Pack Soft Drink', 'Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Canned Soft Drink', 'Chicken Soft Tacos'],
#  ['Steak Burrito', 'Chicken Crispy Tacos'],
#  ['Veggie Bowl', 'Barbacoa Burrito', 'Bottled Water'],
#  ['Chicken Bowl', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Steak Salad'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Steak Bowl', 'Chicken Bowl'],
#  ['Veggie Bowl', 'Chips and Guacamole'],
#  ['Canned Soft Drink', 'Barbacoa Burrito'],
#  ['Steak Bowl', 'Chips and Roasted Chili Corn Salsa'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Steak Bowl', 'Steak Burrito'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Steak Crispy Tacos',
#   'Canned Soft Drink',
#   'Steak Burrito',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl'],
#  ['Barbacoa Bowl', 'Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Nantucket Nectar', 'Chicken Soft Tacos'],
#  ['Steak Bowl', 'Chips and Guacamole'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Chips', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Veggie Bowl', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Steak Burrito'],
#  ['Steak Burrito', 'Bottled Water'],
#  ['Chips',
#   'Chips and Guacamole',
#   'Chips and Fresh Tomato Salsa',
#   'Chicken Crispy Tacos',
#   'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Steak Bowl', 'Chips and Guacamole'],
#  ['Chicken Burrito', 'Side of Chips', 'Canned Soda'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Veggie Salad Bowl', 'Carnitas Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Soft Tacos'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chicken Soft Tacos'],
#  ['Steak Burrito', 'Steak Soft Tacos'],
#  ['Bottled Water', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Carnitas Burrito', 'Veggie Burrito'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Tomatillo-Green Chili Salsa', 'Barbacoa Burrito'],
#  ['Carnitas Bowl', 'Chicken Burrito', 'Chips'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Canned Soft Drink', 'Barbacoa Soft Tacos'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Bowl'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chicken Soft Tacos'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Bottled Water'],
#  ['Carnitas Crispy Tacos', 'Canned Soft Drink', 'Chicken Crispy Tacos'],
#  ['Chicken Burrito', 'Chips and Tomatillo-Green Chili Salsa'],
#  ['Steak Bowl', 'Chips and Guacamole'],
#  ['Chicken Bowl', 'Steak Burrito'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Chicken Bowl'],
#  ['Barbacoa Crispy Tacos',
#   'Chips and Tomatillo-Green Chili Salsa',
#   'Steak Crispy Tacos'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Burrito', '6 Pack Soft Drink'],
#  ['Chicken Burrito', 'Chicken Crispy Tacos'],
#  ['Chicken Burrito', 'Side of Chips', 'Canned Soda'],
#  ['Barbacoa Bowl', 'Chips and Guacamole'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Steak Bowl', 'Chips'],
#  ['Steak Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', '6 Pack Soft Drink'],
#  ['Steak Bowl', 'Side of Chips'],
#  ['Chicken Burrito', 'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Chicken Bowl', 'Izze'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', 'Carnitas Burrito'],
#  ['Chicken Salad', 'Chicken Bowl'],
#  ['Chips and Roasted Chili Corn Salsa', 'Barbacoa Bowl', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Veggie Burrito'],
#  ['Steak Bowl', 'Side of Chips'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Bottled Water'],
#  ['Steak Bowl', 'Chips'],
#  ['Chips and Tomatillo-Green Chili Salsa', 'Steak Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Soft Tacos', 'Steak Bowl'],
#  ['Canned Soft Drink', 'Carnitas Burrito'],
#  ['Chicken Burrito'],
#  ['Chips and Tomatillo-Red Chili Salsa', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chicken Bowl', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Salad Bowl', 'Chicken Bowl'],
#  ['Chicken Salad Bowl'],
#  ['Steak Bowl', 'Chicken Bowl', 'Chips and Guacamole'],
#  ['Steak Burrito', 'Canned Soft Drink'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito'],
#  ['Side of Chips', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Bowl', '6 Pack Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Carnitas Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito', 'Barbacoa Soft Tacos'],
#  ['Chips and Guacamole', 'Carnitas Salad Bowl', 'Steak Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl', 'Bottled Water'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chips and Guacamole', 'Canned Soda', 'Steak Burrito', 'Bottled Water'],
#  ['Steak Burrito', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Steak Bowl'],
#  ['Chips and Roasted Chili Corn Salsa',
#   'Barbacoa Soft Tacos',
#   'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl',
#   'Steak Salad Bowl'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips', 'Chicken Burrito', 'Steak Crispy Tacos', '6 Pack Soft Drink'],
#  ['Chips and Guacamole',
#   'Chicken Burrito',
#   'Chicken Bowl',
#   'Canned Soft Drink'],
#  ['Barbacoa Bowl'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Barbacoa Bowl',
#   'Chips and Tomatillo-Red Chili Salsa',
#   'Bottled Water',
#   'Chips and Roasted Chili-Corn Salsa',
#   'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Carnitas Soft Tacos'],
#  ['Chicken Salad Bowl',
#   'Barbacoa Burrito',
#   'Chips and Guacamole',
#   'Steak Bowl',
#   'Chicken Bowl',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Soft Tacos', 'Veggie Burrito'],
#  ['Carnitas Crispy Tacos', 'Side of Chips'],
#  ['Carnitas Bowl',
#   'Barbacoa Burrito',
#   'Carnitas Burrito',
#   'Chicken Burrito',
#   'Steak Burrito',
#   'Chicken Bowl'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Carnitas Bowl', 'Izze'],
#  ['Chips and Guacamole',
#   'Canned Soda',
#   'Steak Burrito',
#   'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Bowl', 'Chips and Guacamole'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Fresh Tomato Salsa', 'Barbacoa Salad Bowl'],
#  ['Steak Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Barbacoa Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Carnitas Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito', 'Barbacoa Soft Tacos'],
#  ['Veggie Bowl', 'Canned Soft Drink', 'Carnitas Bowl'],
#  ['Steak Bowl', 'Chips and Fresh Tomato Salsa'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Veggie Burrito',
#   'Chips and Fresh Tomato Salsa',
#   'Chips and Guacamole',
#   'Chicken Burrito',
#   'Steak Burrito',
#   'Chips and Tomatillo Green Chili Salsa',
#   '6 Pack Soft Drink'],
#  ['Veggie Burrito'],
#  ['Chips and Tomatillo-Green Chili Salsa', 'Steak Burrito'],
#  ['Barbacoa Bowl', 'Chicken Bowl', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Guacamole', '6 Pack Soft Drink', 'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Steak Burrito', 'Canned Soft Drink'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Chips and Guacamole', 'Carnitas Burrito'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Roasted Chili Corn Salsa', 'Chicken Bowl'],
#  ['Steak Bowl', 'Chips and Guacamole', 'Carnitas Bowl'],
#  ['Chicken Bowl'],
#  ['Veggie Bowl', 'Chicken Bowl'],
#  ['Chips', 'Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Bowl', 'Side of Chips'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Burrito', 'Steak Salad Bowl', 'Steak Burrito'],
#  ['Steak Bowl',
#   'Chips and Fresh Tomato Salsa',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Veggie Salad Bowl', 'Chips and Guacamole'],
#  ['Chips and Guacamole', 'Veggie Bowl'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Steak Burrito', 'Barbacoa Salad Bowl'],
#  ['Chicken Burrito', 'Steak Crispy Tacos'],
#  ['Steak Bowl', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Steak Burrito', 'Barbacoa Soft Tacos'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Carnitas Burrito'],
#  ['Steak Burrito', 'Side of Chips'],
#  ['Carnitas Bowl', 'Chips'],
#  ['Carnitas Bowl',
#   'Chips and Guacamole',
#   'Canned Soft Drink',
#   'Chicken Crispy Tacos'],
#  ['Barbacoa Bowl', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Burrito', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Steak Soft Tacos', 'Chicken Salad Bowl'],
#  ['Steak Bowl', 'Side of Chips', 'Nantucket Nectar'],
#  ['Barbacoa Bowl', 'Chips and Roasted Chili Corn Salsa'],
#  ['Carnitas Bowl', 'Side of Chips', 'Chicken Soft Tacos'],
#  ['Chicken Burrito'],
#  ['Veggie Bowl', 'Chips and Fresh Tomato Salsa'],
#  ['Side of Chips', 'Steak Soft Tacos'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Roasted Chili Corn Salsa',
#   'Chicken Bowl',
#   'Steak Burrito',
#   'Canned Soft Drink'],
#  ['Carnitas Bowl',
#   'Canned Soft Drink',
#   'Bottled Water',
#   'Veggie Bowl',
#   'Chicken Bowl',
#   'Chicken Soft Tacos',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Barbacoa Bowl', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips'],
#  ['Steak Burrito', 'Canned Soft Drink'],
#  ['Carnitas Soft Tacos', 'Barbacoa Soft Tacos'],
#  ['Carnitas Bowl', '6 Pack Soft Drink'],
#  ['Canned Soda', 'Veggie Soft Tacos', 'Veggie Burrito'],
#  ['Chicken Bowl'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl', 'Bottled Water'],
#  ['Veggie Bowl', 'Chicken Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Bottled Water'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Guacamole', 'Salad'],
#  ['Barbacoa Bowl', 'Barbacoa Salad Bowl'],
#  ['Chicken Salad Bowl',
#   'Chips and Guacamole',
#   'Bottled Water',
#   'Chicken Burrito',
#   'Veggie Bowl',
#   'Chicken Bowl',
#   'Chicken Soft Tacos'],
#  ['Chicken Bowl'],
#  ['Carnitas Bowl', 'Canned Soda'],
#  ['Veggie Bowl', 'Chicken Bowl'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Bottled Water'],
#  ['Carnitas Soft Tacos', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Veggie Bowl', 'Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Burrito'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chips and Roasted Chili Corn Salsa', 'Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Steak Crispy Tacos'],
#  ['Veggie Bowl', 'Steak Burrito', 'Chips and Guacamole'],
#  ['Canned Soda', 'Chicken Bowl', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Chicken Salad Bowl', 'Veggie Burrito'],
#  ['Steak Bowl'],
#  ['Chicken Burrito', 'Carnitas Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chicken Salad Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Steak Bowl', 'Chicken Bowl'],
#  ['Bottled Water', 'Chicken Soft Tacos'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Steak Bowl', 'Chicken Burrito', 'Chicken Salad Bowl'],
#  ['Chicken Bowl', 'Bottled Water'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chicken Soft Tacos'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Soft Tacos', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Burrito'],
#  ['Steak Bowl', 'Chicken Bowl'],
#  ['Steak Salad Bowl', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Steak Burrito'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Salad Bowl', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chips and Guacamole',
#   'Chips and Tomatillo-Red Chili Salsa',
#   'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', 'Steak Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Chips', 'Chicken Salad Bowl'],
#  ['Chicken Burrito', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Chips'],
#  ['Chips and Roasted Chili Corn Salsa', 'Chicken Bowl'],
#  ['Steak Bowl', 'Canned Soft Drink'],
#  ['Steak Burrito', 'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Canned Soft Drink', 'Chicken Soft Tacos'],
#  ['Steak Bowl', 'Chicken Burrito', 'Chips and Guacamole'],
#  ['Chicken Burrito', 'Chips and Tomatillo Green Chili Salsa'],
#  ['Steak Salad Bowl',
#   'Canned Soft Drink',
#   'Chips and Guacamole',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl'],
#  ['Chips and Guacamole',
#   'Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl',
#   'Canned Soft Drink'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Steak Burrito'],
#  ['Barbacoa Burrito', 'Nantucket Nectar'],
#  ['Carnitas Soft Tacos', 'Steak Burrito'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Chicken Bowl'],
#  ['Steak Salad Bowl', 'Bottled Water'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Chicken Bowl'],
#  ['Carnitas Bowl', 'Chicken Burrito'],
#  ['Chips and Roasted Chili Corn Salsa', 'Chicken Bowl'],
#  ['Chips', 'Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chicken Salad Bowl', 'Chicken Bowl', 'Chips'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl', 'Izze'],
#  ['Chicken Burrito',
#   'Chicken Soft Tacos',
#   'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chicken Burrito', 'Steak Soft Tacos'],
#  ['Chicken Salad Bowl',
#   'Canned Soft Drink',
#   'Steak Bowl',
#   'Veggie Bowl',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Steak Bowl', 'Chips and Guacamole', 'Bottled Water'],
#  ['Chips and Roasted Chili-Corn Salsa',
#   'Nantucket Nectar',
#   'Carnitas Burrito'],
#  ['Chicken Bowl', 'Chips'],
#  ['Carnitas Crispy Tacos', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chicken Bowl', 'Steak Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Burrito', 'Barbacoa Soft Tacos'],
#  ['Barbacoa Bowl', 'Veggie Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Barbacoa Bowl', 'Chicken Bowl'],
#  ['Veggie Crispy Tacos', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chips and Roasted Chili Corn Salsa',
#   'Chicken Burrito',
#   'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Canned Soda'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chicken Burrito',
#   'Canned Soft Drink',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Carnitas Soft Tacos', 'Barbacoa Soft Tacos'],
#  ['Barbacoa Bowl', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips', 'Carnitas Burrito'],
#  ['Carnitas Bowl', 'Izze'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Chicken Bowl', 'Veggie Salad'],
#  ['Chips and Guacamole', 'Chicken Soft Tacos', 'Veggie Burrito'],
#  ['Chips and Guacamole',
#   'Chicken Burrito',
#   'Chicken Bowl',
#   'Veggie Soft Tacos'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Bowl', 'Nantucket Nectar'],
#  ['Chicken Salad Bowl', 'Chicken Burrito', 'Chicken Bowl', 'Steak Burrito'],
#  ['Chicken Burrito'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Steak Bowl', 'Steak Soft Tacos'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Steak Bowl', 'Chips', 'Bottled Water'],
#  ['Chicken Burrito', 'Bottled Water'],
#  ['Chicken Bowl', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Salad Bowl', 'Chips'],
#  ['Carnitas Bowl'],
#  ['Chicken Bowl'],
#  ['Steak Bowl', 'Canned Soft Drink'],
#  ['Barbacoa Bowl', 'Chicken Burrito'],
#  ['Veggie Bowl', 'Chicken Burrito', 'Chips and Guacamole'],
#  ['Chicken Burrito', 'Bottled Water'],
#  ['Steak Burrito', 'Barbacoa Soft Tacos', '6 Pack Soft Drink'],
#  ['Chicken Salad Bowl', 'Chips and Guacamole', '6 Pack Soft Drink'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl', 'Chips and Tomatillo-Red Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Steak Burrito'],
#  ['Carnitas Bowl', 'Veggie Burrito'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Carnitas Soft Tacos', 'Steak Burrito'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chicken Burrito'],
#  ['Chicken Bowl'],
#  ['Steak Bowl', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Chips', 'Chicken Soft Tacos'],
#  ['Chicken Bowl', 'Chips'],
#  ['Chips and Guacamole', 'Steak Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl'],
#  ['Carnitas Soft Tacos', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Bowl', 'Bottled Water'],
#  ['Chicken Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Barbacoa Bowl', 'Canned Soda'],
#  ['Chicken Salad Bowl', 'Canned Soft Drink'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Burrito', 'Chicken Soft Tacos'],
#  ['Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chicken Salad Bowl', 'Steak Salad Bowl', 'Chips and Guacamole'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Steak Bowl', 'Chicken Burrito', 'Chips and Guacamole'],
#  ['Chips and Fresh Tomato Salsa', 'Barbacoa Salad Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl'],
#  ['Veggie Bowl', 'Side of Chips'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Carnitas Crispy Tacos', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Veggie Bowl',
#   'Chicken Burrito',
#   'Chips and Fresh Tomato Salsa',
#   'Chicken Crispy Tacos'],
#  ['Chicken Burrito'],
#  ['Chips and Tomatillo Green Chili Salsa', 'Barbacoa Burrito'],
#  ['Chicken Bowl', '6 Pack Soft Drink'],
#  ['Chicken Bowl', 'Chips'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chicken Bowl', 'Chips and Tomatillo-Red Chili Salsa'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito', '6 Pack Soft Drink'],
#  ['Veggie Bowl', 'Side of Chips'],
#  ['Barbacoa Crispy Tacos', 'Carnitas Salad Bowl'],
#  ['Steak Bowl', 'Chips and Fresh Tomato Salsa'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips'],
#  ['Carnitas Bowl',
#   'Canned Soft Drink',
#   'Chips and Guacamole',
#   'Chips and Fresh Tomato Salsa',
#   'Bottled Water',
#   'Veggie Bowl',
#   'Chicken Bowl',
#   'Chicken Soft Tacos'],
#  ['Chicken Salad Bowl', 'Veggie Salad Bowl'],
#  ['Chicken Burrito'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Steak Bowl', 'Canned Soft Drink', 'Chips', 'Bottled Water'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Soft Tacos'],
#  ['Chicken Salad Bowl', 'Chips'],
#  ['Steak Bowl', 'Chips'],
#  ['Barbacoa Crispy Tacos'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Carnitas Bowl'],
#  ['Chips and Guacamole', 'Carnitas Burrito'],
#  ['Steak Burrito', 'Steak Soft Tacos'],
#  ['Chicken Bowl', 'Bottled Water', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Carnitas Bowl', '6 Pack Soft Drink'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl', '6 Pack Soft Drink'],
#  ['Chicken Salad Bowl'],
#  ['Steak Bowl', 'Chips and Roasted Chili Corn Salsa'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Steak Bowl', 'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl'],
#  ['Steak Burrito', '6 Pack Soft Drink', 'Chicken Soft Tacos'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Steak Bowl', 'Side of Chips'],
#  ['Steak Bowl', 'Canned Soda', 'Steak Burrito', 'Carnitas Burrito'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Canned Soda', 'Chicken Bowl'],
#  ['Chicken Salad Bowl',
#   'Chips',
#   'Steak Bowl',
#   'Chicken Burrito',
#   'Steak Burrito'],
#  ['Chips and Guacamole',
#   'Chips and Roasted Chili Corn Salsa',
#   'Chicken Soft Tacos',
#   'Veggie Burrito'],
#  ['Carnitas Soft Tacos', 'Bottled Water'],
#  ['Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl', 'Steak Burrito'],
#  ['Barbacoa Bowl', 'Chicken Burrito', 'Chips'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chips and Guacamole', 'Steak Bowl'],
#  ['Chicken Salad Bowl', 'Chips and Guacamole', '6 Pack Soft Drink'],
#  ['Chips and Guacamole', 'Steak Soft Tacos'],
#  ['Chicken Burrito'],
#  ['Canned Soft Drink', 'Veggie Burrito'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole',
#   'Canned Soft Drink',
#   'Barbacoa Soft Tacos',
#   'Bottled Water'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole',
#   'Steak Burrito',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Chips'],
#  ['Carnitas Soft Tacos',
#   'Chicken Bowl',
#   'Canned Soft Drink',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Burrito'],
#  ['Chicken Bowl', 'Chips and Tomatillo-Red Chili Salsa'],
#  ['Barbacoa Bowl', 'Chicken Bowl', 'Chips'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Chips and Guacamole',
#   'Chicken Burrito',
#   'Steak Crispy Tacos',
#   'Steak Burrito'],
#  ['Carnitas Bowl', 'Chicken Burrito', 'Veggie Bowl'],
#  ['Carnitas Bowl',
#   'Chicken Salad Bowl',
#   'Chips and Guacamole',
#   'Chips and Fresh Tomato Salsa',
#   'Carnitas Burrito',
#   'Steak Bowl',
#   'Veggie Bowl',
#   'Chicken Bowl'],
#  ['Chicken Bowl'],
#  ['Veggie Bowl', 'Chicken Burrito'],
#  ['Chicken Burrito'],
#  ['Steak Bowl'],
#  ['Steak Bowl', 'Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Soft Tacos'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Burrito'],
#  ['Steak Burrito', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chicken Burrito'],
#  ['Veggie Bowl', 'Chicken Bowl', 'Chips and Fresh Tomato Salsa'],
#  ['Chicken Bowl', 'Bottled Water'],
#  ['Canned Soft Drink', 'Bottled Water', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Steak Bowl', 'Barbacoa Bowl', 'Chips and Guacamole'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Soft Tacos'],
#  ['Carnitas Soft Tacos', 'Chicken Soft Tacos'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Barbacoa Soft Tacos', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Chicken Soft Tacos', 'Izze'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Carnitas Burrito'],
#  ['Steak Bowl', 'Canned Soft Drink'],
#  ['Chicken Burrito', 'Bottled Water', 'Veggie Burrito'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chicken Burrito', 'Chicken Bowl', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Guacamole', 'Chicken Burrito', '6 Pack Soft Drink'],
#  ['Chicken Salad Bowl', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Carnitas Soft Tacos', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Veggie Bowl', 'Steak Burrito', 'Chips and Fresh Tomato Salsa', 'Chips'],
#  ['Chicken Burrito'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chips and Guacamole', 'Barbacoa Burrito'],
#  ['Chicken Burrito', 'Steak Burrito', 'Canned Soda'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Steak Soft Tacos', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Burrito'],
#  ['Bottled Water', 'Steak Soft Tacos'],
#  ['Chicken Bowl'],
#  ['Steak Bowl', 'Chicken Bowl', 'Chips and Guacamole'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Steak Burrito'],
#  ['Veggie Salad Bowl', 'Chicken Bowl'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito',
#   'Nantucket Nectar',
#   'Chips and Tomatillo-Green Chili Salsa'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Steak Burrito', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Steak Bowl'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Carnitas Bowl', 'Steak Burrito'],
#  ['Steak Bowl'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips', 'Carnitas Soft Tacos'],
#  ['Canned Soda', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Steak Bowl'],
#  ['Chicken Burrito', 'Chicken Bowl', 'Chips'],
#  ['Steak Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Veggie Burrito'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Veggie Salad Bowl', 'Chicken Salad Bowl'],
#  ['Steak Burrito', 'Chicken Soft Tacos'],
#  ['Chicken Bowl', 'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Chips and Guacamole', 'Steak Crispy Tacos', '6 Pack Soft Drink'],
#  ['Carnitas Bowl', 'Steak Bowl'],
#  ['Chicken Burrito', 'Canned Soda', 'Steak Burrito'],
#  ['Carnitas Burrito'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Side of Chips', 'Barbacoa Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink'],
#  ['Carnitas Soft Tacos', 'Barbacoa Soft Tacos'],
#  ['Barbacoa Bowl',
#   'Chips',
#   'Chips and Guacamole',
#   'Steak Soft Tacos',
#   'Chicken Soft Tacos'],
#  ['Chicken Burrito'],
#  ['Chips', 'Chicken Bowl', 'Barbacoa Burrito'],
#  ['Chicken Bowl', 'Barbacoa Soft Tacos'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Carnitas Bowl',
#   'Chips and Guacamole',
#   'Veggie Salad Bowl',
#   'Carnitas Burrito'],
#  ['Steak Bowl'],
#  ['Steak Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Canned Soft Drink',
#   'Veggie Burrito',
#   'Bottled Water',
#   'Steak Bowl',
#   'Chicken Bowl',
#   'Chicken Soft Tacos',
#   'Chips and Tomatillo Red Chili Salsa'],
#  ['Chicken Burrito'],
#  ['Chicken Burrito', 'Chicken Soft Tacos'],
#  ['Chicken Burrito', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Burrito'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chips and Tomatillo Green Chili Salsa',
#   'Chicken Bowl',
#   'Canned Soft Drink'],
#  ['Carnitas Soft Tacos'],
#  ['Chicken Burrito', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Chips and Guacamole', 'Chicken Burrito'],
#  ['Chicken Salad Bowl',
#   'Barbacoa Burrito',
#   'Steak Bowl',
#   'Chicken Burrito',
#   'Steak Burrito',
#   'Veggie Bowl',
#   'Chicken Bowl'],
#  ['Steak Burrito'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips and Tomatillo Red Chili Salsa'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chicken Bowl'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chicken Bowl'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chicken Bowl', 'Chips', 'Bottled Water'],
#  ['Chips and Roasted Chili Corn Salsa',
#   'Chicken Burrito',
#   'Canned Soft Drink'],
#  ['Chips and Guacamole', 'Canned Soft Drink', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Bowl', 'Canned Soft Drink', 'Chips'],
#  ['Chicken Bowl', 'Side of Chips'],
#  ['Chicken Burrito', 'Chicken Bowl', 'Canned Soft Drink'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Carnitas Bowl', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips and Roasted Chili-Corn Salsa'],
#  ['Barbacoa Bowl',
#   'Chips and Roasted Chili Corn Salsa',
#   'Chicken Crispy Tacos',
#   '6 Pack Soft Drink'],
#  ['Veggie Bowl', 'Chicken Bowl', 'Steak Burrito'],
#  ['Steak Burrito', 'Nantucket Nectar'],
#  ['Chicken Bowl', 'Veggie Soft Tacos', 'Carnitas Burrito'],
#  ['Chips and Guacamole', 'Chicken Burrito', '6 Pack Soft Drink', 'Steak Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Veggie Bowl', 'Chicken Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Steak Burrito', 'Chips'],
#  ['Barbacoa Bowl',
#   'Chicken Salad Bowl',
#   'Carnitas Bowl',
#   'Barbacoa Burrito',
#   'Steak Bowl',
#   'Steak Burrito',
#   'Steak Salad Bowl'],
#  ['Chicken Bowl'],
#  ['Chicken Bowl', 'Side of Chips', 'Bottled Water'],
#  ['Chicken Bowl', 'Bottled Water'],
#  ['Chicken Burrito'],
#  ['Steak Bowl', 'Bottled Water'],
#  ['Chicken Burrito', 'Steak Crispy Tacos'],
#  ['Chicken Salad Bowl'],
#  ['Chicken Burrito', 'Chips'],
#  ['Chicken Salad Bowl', 'Chicken Crispy Tacos', 'Chips'],
#  ['Chips and Tomatillo Red Chili Salsa', 'Veggie Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl', 'Nantucket Nectar'],
#  ['Steak Bowl', 'Barbacoa Soft Tacos', 'Chips'],
#  ['Chips and Fresh Tomato Salsa', 'Steak Burrito'],
#  ['Chicken Bowl', 'Steak Burrito'],
#  ['Steak Salad Bowl', 'Canned Soft Drink'],
#  ['Bottled Water', 'Barbacoa Salad Bowl'],
#  ['Veggie Bowl', 'Canned Soda', 'Chips and Fresh Tomato Salsa'],
#  ['Chicken Burrito', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Steak Soft Tacos'],
#  ['Chicken Soft Tacos', 'Carnitas Burrito'],
#  ['Steak Bowl', 'Chicken Burrito', 'Bottled Water'],
#  ['Chicken Bowl', 'Steak Crispy Tacos', 'Bottled Water'],
#  ['Chicken Burrito', 'Barbacoa Burrito'],
#  ['Chips and Guacamole', 'Chips', 'Chicken Soft Tacos'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Steak Burrito'],
#  ['Veggie Bowl', 'Side of Chips'],
#  ['Steak Bowl'],
#  ['Chips and Guacamole', 'Steak Burrito'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Canned Soft Drink', 'Steak Burrito'],
#  ['Veggie Burrito'],
#  ['Chicken Bowl'],
#  ['Chicken Burrito', 'Steak Burrito'],
#  ['Carnitas Bowl', 'Chicken Bowl'],
#  ['Chips and Guacamole', 'Chicken Burrito', 'Canned Soft Drink'],
#  ['Chips and Fresh Tomato Salsa', 'Canned Soda', 'Steak Burrito'],
#  ['Chicken Bowl', 'Chips'],
#  ['Chips and Guacamole', 'Chicken Bowl'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Chicken Burrito', 'Side of Chips'],
#  ['Chips and Guacamole', 'Chicken Bowl', 'Steak Burrito'],
#  ['Steak Burrito', 'Chicken Crispy Tacos', 'Chicken Soft Tacos'],
#  ['Chicken Bowl'],
#  ['Chips and Fresh Tomato Salsa', 'Chicken Bowl'],
#  ['Canned Soft Drink',
#   'Chicken Crispy Tacos',
#   'Steak Burrito',
#   'Chicken Soft Tacos'],
#  ['Barbacoa Bowl', 'Chicken Bowl'],
#  ...]

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

te = TransactionEncoder()
te_ary = te.fit(df_tmp_arr).transform(df_tmp_arr)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
frequent_itemsets = apriori(df, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                                itemsets
# 0   0.083969                         (Bottled Water)
# 1   0.051254                           (Canned Soda)
# 2   0.150491                     (Canned Soft Drink)
# 3   0.335333                          (Chicken Bowl)
# 4   0.266630                       (Chicken Burrito)
# 5   0.053435                    (Chicken Salad Bowl)
# 6   0.058342                    (Chicken Soft Tacos)
# 7   0.113413                                 (Chips)
# 8   0.059978          (Chips and Fresh Tomato Salsa)
# 9   0.258451                   (Chips and Guacamole)
# 10  0.055071                         (Side of Chips)
# 11  0.102508                            (Steak Bowl)
# 12  0.186478                         (Steak Burrito)
# 13  0.060523       (Chicken Bowl, Canned Soft Drink)
# 14  0.066521                   (Chicken Bowl, Chips)
# 15  0.081243     (Chips and Guacamole, Chicken Bowl)
# 16  0.062159  (Chips and Guacamole, Chicken Burrito)
